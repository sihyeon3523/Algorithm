# %%
# 2739
N = int(input())
for i in range(1,10):
    print("%d * %d = %d" %(N,i,N*i))
# Out:
# 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %%
# 10950
for i in range(int(input())):
    a, b = map(int, input().split())
    print(a+b)
# Out:
# 5
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7

# %%
# 8393
n = 0
for i in range(1, int(input())+1):
    n += i 
print(n)
# Out:
# 5
# 15

# %%
# 15552
#주피터에서는 stdin 이 제대로 구성되어 있지 않기 때문에 
#stdin.readline() 을 실행하면 입력을 받지 못하고 항상 빈 문자열이 반환된다.
#sydin.readline() 대신에 input() 을 사용해야 한다. 
"""
import sys

for i in range(int(sys.stdin.readline())):
    x, y = map(int, sys.stdin.readline().split())
    print(x+y)
"""
# Out:
# '\nimport sys\n\nfor i in range(int(sys.stdin.readline())):\n    x, y = map(int, sys.stdin.readline().split())\n    print(x+y)\n'

# %%
# 2741
for i in range(1,int(input())+1):
    print(i)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5

# %%
# 2742
for i in range(int(input()),0,-1):
    print(i)
# Out:
# 5
# 5
# 4
# 3
# 2
# 1

# %%
# 11021
n = int(input())

for i in range(1,n+1):
    x, y = map(int, input().split())
    print("Case #%d: %d" %(i,x+y))
# Out:
# 5
# 1 1
# Case #1: 2
# 2 3
# Case #2: 5
# 3 4
# Case #3: 7
# 9 8
# Case #4: 17
# 5 2
# Case #5: 7

# %%
# 11022
n = int(input())

for i in range(1,n+1):
    x, y = map(int, input().split())
    print("Case #%d: %d + %d = %d" %(i,x, y, x+y))
# Out:
# 5
# 1 1
# Case #1: 1 + 1 = 2
# 2 3
# Case #2: 2 + 3 = 5
# 3 4
# Case #3: 3 + 4 = 7
# 9 8
# Case #4: 9 + 8 = 17
# 5 2
# Case #5: 5 + 2 = 7

# %%
# 2438
n = int(input())

for i in range(1, n+1):
    print("*"*i)
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %%
# 2439
n = int(input())

for i in range(1, n+1):
    print(" "*(n-i)+"*"*i)
    #print("{0:>{1}}".format("*"*i,n))
# Out:
# 3
#   *
#  **
# ***

# %%
# 10871
a, b = map(int, input().split())
c = list(map(int,input().split()))

for i in c: 
    if i < b:
        print(i, end=" ")
# Out:
# 10 5
# 1 10 4 9 2 3 8 5 7 6
# 1 4 2 3
