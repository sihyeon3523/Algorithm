# %%
# 2557
print("Hello World!")
# Out:
# Hello World!

# %%
# 10718
print("We love kriii")
# Out:
# We love kriii

# %%
# 10718
##역슬래시 방법 
print("강한친구 대한육군\n강한친구 대한육군")

##docstring 방법 
print("""강한친구 대한육군
강한친구 대한육군""")
# Out:
# 강한친구 대한육군
# 강한친구 대한육군
# 강한친구 대한육군
# 강한친구 대한육군

# %%
# 10171
#이스케이프 문자(별도의 기능을 제공하는 특수한 문자, 앞에 역슬래시(\)가 있음)
#역슬래시가 단독으로 쓰이면 이스케이프 문자로 인식
#역슬래시를 두번 사용함으로 하나의 역슬래시를 출력할 수 있음 
print("""\    /\\
 )  ( ')
(  /  )
 \(__)|""")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
# 10172
print('''|\_/|
|q p|   /}
( 0 )"""\\
|"^"`    |
||_/=\\\__|
''')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %%
# 1000
a, b = map(int, input().split())
print(a+b)
# Out:
# 1 2
# 3

# %%
# 1001
a, b = map(int, input().split())
print(a-b)
# Out:
# 3 2
# 1

# %%
# 10998
a, b = map(int, input().split())
print(a*b)
# Out:
# 1 2
# 2

# %%
# 1008
a, b = map(int, input().split())
print(a/b)
# Out:
# 1 3
# 0.3333333333333333

# %%
# 10869
a, b = map(int, input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %%
# 10430
a, b, c = map(int, input().split())
print((a+b)%c)
print(((a%c)+(b%c))%c)
print((a*b)%c)
print(((a%c)*(b%c))%c)
# Out:
# 5 8 4
# 1
# 1
# 0
# 0

# %%
# 2588
a = int(input())
b = input()
print(a*int(b[2]))
print(a*int(b[1]))
print(a*int(b[0]))
print(a*int(b))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720
